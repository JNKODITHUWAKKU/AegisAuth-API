# %%
# 1. Install dependencies\s
# !pip install ultralytics roboflow --quiet

# %%
# !python getdataset.py

# %%
# !python check_class_imbalance.py
# Out:
# --- Current Class Distribution ---
# Fake (Class 0): 10916
# Real (Class 1): 6305
# ----------------------------------
#
# [SYSTEM] Plot saved to /content/face-anti-spoofing-detection-2/class_imbalance_plot.png

# %%
# !python undersample.py
# Out:
# [SYSTEM] Balancing dataset natively to remove majority class bias...
# [train] Undersampling 4120 majority (Fake) images...
# [valid] Undersampling 210 majority (Fake) images...
# [test] Undersampling 89 majority (Fake) images...
# [SYSTEM] Dataset balancing complete. Relocated 4419 excess images.

# %%
# !python check_class_imbalance.py
# Out:
# --- Current Class Distribution ---
# Fake (Class 0): 6440
# Real (Class 1): 6305
# ----------------------------------
#
# [SYSTEM] Plot saved to /content/face-anti-spoofing-detection-2/class_imbalance_plot.png

# %%
# !python train_liveness.py
# Out:
# [SYSTEM] Initializing Liveness Engine with Anti-Overfitting Protocols...
# ...
# Ultralytics 8.4.96 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
